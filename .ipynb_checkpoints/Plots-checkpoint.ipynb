# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt

# Considerações do professor:
# Colocar início e fim nos gráficos de barra
# Topar o 0 na margem
# Usar pontos e tracos ao invés de cores no gráfico de linhas
# Usar cor menos vibrantes

# %%
# Resultados para spotify em primeiro plano

seq00 = [0.889, 1.048, 1.12, 1.18, 1.249, 1.329, 1.459, 1.681, 1.917, 2.433, 2.653, 2.876, 3.075, 3.223,
       3.422, 3.621, 3.811, 4.032, 4.155, 4.37, 4.767, 4.987, 5.183, 5.388, 5.538, 5.719, 5.858, 5.93, 6.029,
       6.208]

N = len(seq00)
x = range(1,31)
width = 1/1.1
z = [i * 1.2 for i in seq00]
plt.bar(x, seq00, width, color="c")
#plt.plot(x, seq, color="black", marker=',', linestyle=':', linewidth=2)
plt.grid(True)
plt.ylim(0,10)
plt.plot([1], [1], 'o')
plt.plot([30], [6.2], 'o')
plt.annotate('0.889J', xy=(1, 1), xytext=(0.05, 1.5))
plt.annotate('6.208J', xy=(30, 6.2), xytext=(28.5, 6.5))
#plt.title("Consumo de energia do app Spotify (Em primeiro plano)")
plt.xlabel("Observações")
plt.ylabel("Energia (Joules)")

plt.show()

# %%
# Resultados para deezer em primeiro plano

seq01 = [3.296, 3.737, 3.943, 4.318, 4.521, 4.894, 5.117, 5.309, 5.522, 5.662, 6.046, 6.24, 6.392, 6.562, 6.722, 6.91,
7.132,7.241, 7.382, 7.516, 7.875, 7.987, 8.179, 8.337, 8.532, 8.822, 9.039, 9.237, 9.45, 9.682]

N = len(seq01)
x = range(1,31)
width = 1/1.2
plt.bar(x, seq01, width, color="c")
plt.grid(True, color='gray')
plt.ylim(0,10)
plt.annotate('3.296J', xy=(1, 1), xytext=(0.1,3.9))
plt.annotate('9.682J', xy=(30, 6.2), xytext=(28, 9))
plt.plot([1], [3.296], 'o')
plt.plot([30], [9.682], 'o')
#plt.title("Consumo de energia do app Deezer (Em primeiro plano)")
plt.xlabel("Observações")
plt.ylabel("Energia (Joules)")
plt.show()

# %%
# Resultados para palco mp3 em primeiro plano

seq02 = [2.054, 2.392, 2.721, 3.145, 3.28, 4.249, 4.547, 4.7, 4.827, 5.136, 5.301, 5.4, 5.519, 5.998, 6.278, 6.404, 6.614, 
       6.921, 7.433, 7.629, 7.87, 8.277, 8.488, 8.488, 8.714, 8.714, 8.935, 9.255, 10.164, 10.164]

N = len(seq02)
x = range(1,31)
width = 1/1.2
plt.bar(x, seq02, width, color="c")
plt.ylim(0,10)
plt.grid(True, color='gray')
plt.annotate(str(seq02[0])+"J", xy=(1, 1), xytext=(0.1,3))
plt.annotate(str(seq02[29])+"J", xy=(30, 6.2), xytext=(28, 9))
plt.plot([1], [seq02[0]], 'o')
plt.plot([30], [seq02[29]], 'o')
#plt.title("Consumo de energia do app Palco MP3 (Em primeiro plano)")
plt.xlabel("Observações")
plt.ylabel("Energia (Joules)")
plt.show()

# %%
# Resultados para spotify em segundo plano

seq10 = [2.196, 2.272, 2.333, 2.333, 2.392, 2.392, 2.411, 2.435, 2.435, 2.452, 2.452, 2.472, 2.472, 2.497, 2.497,
2.515, 2.515, 2.528, 2.528, 2.551, 2.551, 2.568, 2.568, 2.595, 2.628, 2.658, 2.658, 2.681, 2.681, 2.705]

N = len(seq10)
x = range(1,31)
width = 1/1.2
plt.bar(x, seq10, width, color="green")
plt.ylim(0,10)
plt.grid(True, color='gray')
plt.annotate(str(seq10[0])+"J", xy=(1, 1), xytext=(0.1,2.5))
plt.annotate(str(seq10[29])+"J", xy=(30, 6.2), xytext=(28.5, 2.9))

plt.plot([1], [seq10[0]], 'o')
plt.plot([30], [seq10[29]], 'o')
# plt.title("Consumo de energia do app Spotify (Em segundo plano)")
plt.xlabel("Observações")
plt.ylabel("Energia (Joules)")
plt.show()

# %%
# Resultados para deezer em segundo plano

seq11 = [0.935, 0.935, 0.996, 0.996, 0.996, 0.996, 1.042, 1.042, 1.101, 1.181, 1.262, 1.262, 1.301, 1.301, 1.353, 
       1.353, 1.405, 1.405, 1.454, 1.454, 1.506, 1.506, 1.559, 1.559, 1.597, 1.597, 1.66, 1.66, 1.695, 1.695,]

N = len(seq11)
x = range(1,31)
width = 1/1.2
plt.bar(x, seq11, width, color="green")
plt.ylim(0,10)
plt.grid(True, color='gray')
plt.annotate(str(seq11[0])+"J", xy=(1, 1), xytext=(0.1,1.6))
plt.annotate(str(seq11[29])+"J", xy=(30, 6.2), xytext=(28.5, 2.2))
plt.plot([1], [seq11[0]], 'o')
plt.plot([30], [seq11[29]], 'o')
#plt.title("Consumo de energia do app Deezer (Em segundo plano)")
plt.xlabel("Observaçoes")
plt.ylabel("Energia (Joules)")
plt.show()

# %%
# Resultados para Palco MP3 em segundo plano

seq12 = [2.34, 2.448, 2.595, 2.653, 2.738, 2.738, 2.794, 2.794, 2.844, 2.844, 2.89, 2.89, 2.939, 2.939, 2.982, 2.982, 
       3.028, 3.028, 3.069, 3.069, 3.127, 3.127, 3.167, 3.167, 3.212, 3.212, 3.261, 3.261, 3.313, 3.365]

N = len(seq12)
x = range(1,31)
width = 1/1.2
plt.bar(x, seq12, width, color="green")
plt.ylim(0,10)
plt.grid(True, color='gray')
plt.annotate(str(seq12[0])+"J", xy=(1, 1), xytext=(0.1,2.7))
plt.annotate(str(seq12[29])+"J", xy=(30, 6.2), xytext=(28.5, 3.8))
plt.plot([1], [seq12[0]], 'o')
plt.plot([30], [seq12[29]], 'o')
#plt.title("Consumo de energia do app Palco MP3 (Em segundo plano)")
plt.xlabel("Observações")
plt.ylabel("Energia (Joules)")
plt.show()

# %%
# Consumo dos três apps em primeiro plano (compilado)

plt.xlabel('X')
plt.ylabel('Y')
#plt.title('Comparativo de energia dos apps em primeiro plano')
a, = plt.plot(seq00, label='Spotify', linestyle='--')
b, = plt.plot(seq01, label='Deezer', linestyle='-.')
c, = plt.plot(seq02, label='Palco MP3')

plt.annotate(str(seq00[0])+"J", xy=(1, seq00[0]+0.3), xytext=(0,seq00[0]+0.3))
plt.plot([0], [seq00[0]], 'o')
plt.annotate(str(seq00[29])+"J", xy=(29, seq00[29]+0.3), xytext=(29,seq00[29]+0.3))
plt.plot([29], [seq00[29]], 'o')

plt.annotate(str(seq01[0])+"J", xy=(0.6, seq01[0]+0.3), xytext=(0,seq01[0]+0.3))
plt.plot([0], [seq01[0]], 'o')
plt.annotate(str(seq01[29])+"J", xy=(29, seq01[29]+0.3), xytext=(27.5,seq01[29]-0.7))
plt.plot([29], [seq01[29]], 'o')

plt.annotate(str(seq02[0])+"J", xy=(1, seq02[0]+0.3), xytext=(0,seq02[0]+0.3))
plt.plot([0], [seq02[0]], 'o')
plt.annotate(str(seq02[29])+"J", xy=(29, seq02[29]+0.3), xytext=(29,seq02[29]+0.3))
plt.plot([29], [seq02[29]], 'o')

plt.xlabel("Observações")
plt.grid(True, color='gray')
plt.ylabel("Energia (Joules)")
plt.legend(handles=[b,c,a])
plt.show()

# %%
# Consumo dos três apps em segundo plano (compilado)

plt.xlabel('X')
plt.ylabel('Y')
#plt.title('Comparativo de energia dos apps em segundo plano')
a, = plt.plot(seq10, label='Spotify', linestyle='--')
b, = plt.plot(seq11, label='Deezer', linestyle='-.')
c, = plt.plot(seq12, label='Palco MP3')
plt.xlabel("Observações")
plt.ylim(0,10)

plt.annotate(str(seq10[0])+"J", xy=(1, seq10[0]+0.3), xytext=(0,seq10[0]-0.6))
plt.plot([0], [seq10[0]], 'o', color='blue')
plt.annotate(str(seq10[29])+"J", xy=(29, seq10[29]+0.3), xytext=(29,seq10[29]+0.3))
plt.plot([29], [seq10[29]], 'o', color='blue')

plt.annotate(str(seq11[0])+"J", xy=(1, seq11[0]+0.3), xytext=(0,seq11[0]-0.6))
plt.plot([0], [seq11[0]], 'o')
plt.annotate(str(seq11[29])+"J", xy=(29, seq11[29]+0.3), xytext=(29,seq11[29]+0.3))
plt.plot([29], [seq11[29]], 'o')

plt.annotate(str(seq12[0])+"J", xy=(1, seq12[0]+0.3), xytext=(0,seq12[0]+0.3))
plt.plot([0], [seq00[0]], 'o')
plt.annotate(str(seq12[29])+"J", xy=(29, seq12[29]+0.3), xytext=(29,seq12[29]+0.3))
plt.plot([29], [seq12[29]], 'o')

plt.grid(True, color='gray')
plt.grid(True, color='gray')
plt.ylabel("Energia (Joules)")
plt.legend(handles=[c,a,b])
plt.show()

# %%
# Comparativo total de energia em primeiro plano

lis = ["Spotify", "Deezer", "Palco MP3"]
seqall = [105.15, 201.6, 109.6]

N = len(seqall)
x = range(N)
width = 1/1.2
plt.bar(x,seqall, width, color="c")
plt.xticks(x, lis)
plt.grid(True, color='gray')
plt.ylim(0,240)
plt.annotate("105.15J", xy=(0.5, seq12[0]+0.3), xytext=(-0.0010,108))
plt.annotate("201.6J", xy=(0.5, seq12[0]+0.3), xytext=(0.9,205))
plt.annotate("109.6J", xy=(0.5, seq12[0]+0.3), xytext=(1.9,115))
#plt.title("Comparativo total de energia (Em primeiro plano)")
plt.ylabel("Energia (Joules)")
plt.xlabel("Aplicativos de streaming de música")
plt.show()

# %%
# Comparativo total de energia em segundo plano

lis = ["Spotify", "Deezer", "Palco MP3"]
seqall = [74.97, 39.8, 88.8]

N = len(seqall)
x = range(N)
width = 1/1.2
plt.bar(x,seqall, width, color="c")
plt.xticks(x, lis)
plt.ylim(0,240)
plt.grid(True, color='gray')
plt.annotate("74.97J", xy=(0.5, seq12[0]+0.3), xytext=(-0.0010,80))
plt.annotate("39.8J", xy=(0.5, seq12[0]+0.3), xytext=(0.9,45))
plt.annotate("88.8J", xy=(0.5, seq12[0]+0.3), xytext=(1.9,94))
#plt.title("Comparativo total de energia (Em segundo plano)")
plt.xlabel("Aplicativos de streaming de música")
plt.ylabel("Energia (Joules)")
plt.show()
